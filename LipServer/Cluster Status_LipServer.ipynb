# %%
from sklearn.cluster import KMeans
from sklearn.externals import joblib

import math
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
fileName = 'learning_1_saved.sav'

df2 = joblib.load(fileName)
sb.lmplot('x','y',data = df2, fit_reg=False, scatter_kws={"s":150}, hue="cluster")
plt.title('Learning_1_result')
# Out:
# Text(0.5,1,'Learning_1_result')
